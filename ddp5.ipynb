# %%
pilih = int(input("""selamat datang di aplikasi menghitung
1. untuk menghitung luas Persegi
2. untuk menghitung luas lingkaran
3. untuk menghitung luas segitiga \n"""))

match pilih:
   case 1 :
      print("kamu memilih 1 untuk menghitung luas persegi")
      sisi = int(input("masukan sisi persegi: "))
      LuasPersegi = sisi*sisi
      print("luas persegi yang sisinya", sisi, "adalah", LuasPersegi)

   case 2 :
      print("kamu memilih 2 untuk menghitung luas lingkaran")
      jari2 = int(input("masukan jari2 lingkaran: "))
      LuasLkr = 3.14 * jari2 * jari2
      print("luas lingkaran yang jari-jarinya", jari2, "adalah", LuasLkr)

   case 3 :
      print("kamu memilih 3 untuk menghitung luas segitiga")
      alas = int(input("masukan alas segitiga: "))
      tinggi = int(input("masukan tinggi segitiga: "))
      LuasSgt = 0.5 * alas * tinggi
      print("luas persegi dengan alas", alas, "dan tinggi", tinggi, "adalah", LuasSgt)

   case _ :
      print("Anda salah pilih")
# Out:
# selamat datang di aplikasi menghitung
# 1. untuk menghitung luas Persegi
# 2. untuk menghitung luas lingkaran
# 3. untuk menghitung luas segitiga
# 1
# kamu memilih 1 untuk menghitung luas persegi
# masukan sisi persegi: 6
# luas persegi yang sisinya 6 adalah 36

# %%
pilih = int(input("""selamat datang di aplikasi menghitung
1. untuk menghitung luas Persegi
2. untuk menghitung luas lingkaran
3. untuk menghitung luas segitiga \n"""))

match pilih:
   case 1 :
      print("kamu memilih 1 untuk menghitung luas persegi")
      sisi = int(input("masukan sisi persegi: "))
      LuasPersegi = sisi*sisi
      print("luas persegi yang sisinya", sisi, "adalah", LuasPersegi)

   case 2 :
      print("kamu memilih 2 untuk menghitung luas lingkaran")
      jari2 = int(input("masukan jari2 lingkaran: "))
      LuasLkr = 3.14 * jari2 * jari2
      print("luas lingkaran yang jari-jarinya", jari2, "adalah", LuasLkr)

   case 3 :
      print("kamu memilih 3 untuk menghitung luas segitiga")
      alas = int(input("masukan alas segitiga: "))
      tinggi = int(input("masukan tinggi segitiga: "))
      LuasSgt = 0.5 * alas * tinggi
      print("luas persegi dengan alas", alas, "dan tinggi", tinggi, "adalah", LuasSgt)

   case _ :
      print("Anda salah pilih")
# Out:
# selamat datang di aplikasi menghitung
# 1. untuk menghitung luas Persegi
# 2. untuk menghitung luas lingkaran
# 3. untuk menghitung luas segitiga
# 2
# kamu memilih 2 untuk menghitung luas lingkaran
# masukan jari2 lingkaran: 8
# luas lingkaran yang jari-jarinya 8 adalah 200.96

# %%
pilih = int(input("""selamat datang di aplikasi menghitung
1. untuk menghitung luas Persegi
2. untuk menghitung luas lingkaran
3. untuk menghitung luas segitiga \n"""))

match pilih:
   case 1 :
      print("kamu memilih 1 untuk menghitung luas persegi")
      sisi = int(input("masukan sisi persegi: "))
      LuasPersegi = sisi*sisi
      print("luas persegi yang sisinya", sisi, "adalah", LuasPersegi)

   case 2 :
      print("kamu memilih 2 untuk menghitung luas lingkaran")
      jari2 = int(input("masukan jari2 lingkaran: "))
      LuasLkr = 3.14 * jari2 * jari2
      print("luas lingkaran yang jari-jarinya", jari2, "adalah", LuasLkr)

   case 3 :
      print("kamu memilih 3 untuk menghitung luas segitiga")
      alas = int(input("masukan alas segitiga: "))
      tinggi = int(input("masukan tinggi segitiga: "))
      LuasSgt = 0.5 * alas * tinggi
      print("luas persegi dengan alas", alas, "dan tinggi", tinggi, "adalah", LuasSgt)

   case _ :
      print("Anda salah pilih")
# Out:
# selamat datang di aplikasi menghitung
# 1. untuk menghitung luas Persegi
# 2. untuk menghitung luas lingkaran
# 3. untuk menghitung luas segitiga
# 3
# kamu memilih 3 untuk menghitung luas segitiga
# masukan alas segitiga: 4
# masukan tinggi segitiga: 6
# luas persegi dengan alas 4 dan tinggi 6 adalah 12.0

# %%
kendaraan=["porsche", "mobil", 1000, "black", "roda 4"]
print(kendaraan)

kendaraan.append("100.000.000.000 matic")
print(kendaraan)

kendaraan.insert(2,"Lamborghini")
print(kendaraan)
# Out:
# ['porsche', 'mobil', 1000, 'black', 'roda 4']
# ['porsche', 'mobil', 1000, 'black', 'roda 4', '100.000.000.000 matic']
# ['porsche', 'mobil', 'Lamborghini', 1000, 'black', 'roda 4', '100.000.000.000 matic']
